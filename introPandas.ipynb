# %%
import pandas as pd

venda = { 'data': ['22/02/2023', '23/02/2023'],
        'valor': [500, 300],
        'produto': ['batata', 'maças'],
        'qntde': [50,70],
        }
vendas_df = pd.DataFrame(venda)
display(vendas_df) # display é igual ao pd.DataFrame(variavel)
# Out:
#          data  valor produto  qntde
# 0  22/02/2023    500  batata     50
# 1  23/02/2023    300   maças     70

# %%
vendas_df = pd.read_excel('Vendass.xlsx')
#pd.DataFrame(vendas_df.head(10))

display(vendas_df.shape())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qd/x3k2s6613jl16cjc3419phj80000gp/T/ipykernel_2761/2875670738.py in <module>
#       2 #pd.DataFrame(vendas_df.head(10))
#       3
# ----> 4 display(vendas_df.shape())
#
# TypeError: 'tuple' object is not callable

# %%
display(vendas_df.describe())

# %%
produtos = vendas_df[['Produto', 'ID Loja']]
display(produtos)

# %%
display(vendas_df.loc[1:5])
# Out:
#    Código Venda       Data         ID Loja        Produto  Quantidade  \
# 1             1 2019-01-01     Nova Arcada       Camiseta           2
# 2             1 2019-01-01     Nova Arcada  Sapato Xadrez           1
# 3             2 2019-01-02  Norte Shopping        Relógio           3
# 4             2 2019-01-02  Norte Shopping   Chinelo Liso           1
# 5             3 2019-01-02    Braga Parque    Cinto Linho           1
#
#    Valor Unitário  Valor Final
# 1             180          360
# 2             368          368
# 3             200          600
# 4              71           71
# 5             248          248

# %%
vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping']
display(vendas_norteshopping_df)
# Out:
#        Código Venda       Data         ID Loja                 Produto  \
# 3                 2 2019-01-02  Norte Shopping                 Relógio
# 4                 2 2019-01-02  Norte Shopping            Chinelo Liso
# 8                 7 2019-01-02  Norte Shopping  Camisa Gola V Listrado
# 9                 7 2019-01-02  Norte Shopping             Camisa Liso
# 100              73 2019-01-02  Norte Shopping            Cueca Xadrez
# ...             ...        ...             ...                     ...
# 93716         64888 2019-11-30  Norte Shopping             Polo Xadrez
# 93754         64914 2019-11-30  Norte Shopping              Calça Liso
# 93755         64914 2019-11-30  Norte Shopping          Casaco Estampa
# 93756         64914 2019-11-30  Norte Shopping                   Gorro
# 93852         64980 2019-11-30  Norte Shopping           Bermuda Linho
#
#        Quantidade  Valor Unitário  Valor Final
# 3               3             200          600
# 4               1              71           71
# 8               1             116          116
# 9               1             105          105
# 100             5              60          300
# ...           ...             ...          ...
# 93716           1             142          142
# 93754           1             190          190
# 93755           2             256          512
# 93756           2              80          160
# 93852           1             195          195
#
# [3924 rows x 7 columns]

# %%
vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping',['ID Loja','Produto', 'Quantidade']]
display(vendas_norteshopping_df)

# %%
vendas_df['comissão'] = vendas_df['Valor Final'] * 0.05
display(vendas_df)
# Out:
#        Código Venda       Data                     ID Loja            Produto  \
# 0                 1 2019-01-01                 Nova Arcada     Sapato Estampa
# 1                 1 2019-01-01                 Nova Arcada           Camiseta
# 2                 1 2019-01-01                 Nova Arcada      Sapato Xadrez
# 3                 2 2019-01-02              Norte Shopping            Relógio
# 4                 2 2019-01-02              Norte Shopping       Chinelo Liso
# ...             ...        ...                         ...                ...
# 93905         65012 2019-11-30         Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30           Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30           Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30  Shopping Armazém do Chiado     Pulseira Linho
# 93909         65014 2019-11-30  Shopping Armazém do Chiado      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  comissão
# 0               1             358          358     17.90
# 1               2             180          360     18.00
# 2               1             368          368     18.40
# 3               3             200          600     30.00
# 4               1              71           71      3.55
# ...           ...             ...          ...       ...
# 93905           2             283          566     28.30
# 93906           2              79          158      7.90
# 93907           3              67          201     10.05
# 93908           5             114          570     28.50
# 93909           4             259         1036     51.80
#
# [93910 rows x 8 columns]

# %%
vendas_df.loc[:,'Imposto'] = 0
display(vendas_df)

# %%
vendas_dez_df = pd.read_excel('Vendass - Dez.xlsx')
#display(vendas_dez_df)

vendas_df = vendas_df.append(vendas_dez_df)
display(vendas_df)
# Out:
# /var/folders/qd/x3k2s6613jl16cjc3419phj80000gp/T/ipykernel_2761/1861355986.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vendas_df = vendas_df.append(vendas_dez_df)
#       Código Venda       Data            ID Loja           Produto  \
# 0                1 2019-01-01        Nova Arcada    Sapato Estampa
# 1                1 2019-01-01        Nova Arcada          Camiseta
# 2                1 2019-01-01        Nova Arcada     Sapato Xadrez
# 3                2 2019-01-02     Norte Shopping           Relógio
# 4                2 2019-01-02     Norte Shopping      Chinelo Liso
# ...            ...        ...                ...               ...
# 7084         69996 2019-12-26       Forum Aveiro   Calção Listrado
# 7085         69996 2019-12-26       Forum Aveiro           Mochila
# 7086         69996 2019-12-26       Forum Aveiro  Pulseira Estampa
# 7087         69997 2019-12-26  Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26  Ribeirão Shopping      Calção Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              1             358          358
# 1              2             180          360
# 2              1             368          368
# 3              3             200          600
# 4              1              71           71
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [108088 rows x 7 columns]

# %%
vendas_df = vendas_df.dropna(how='all', axis=1) #Apagar linhas e colunas completamente vazias
vendas_df = vendas_df.dropna() # basta ter um elemento vazio
# Preencher os valores vaizos com uma media da coluna
vendas_df['Comissão'] = vendas_df['Comissão'].fillna(vendas_df['Comissão']).mean()
# Preencher com o ultimo valor
vendas_df
